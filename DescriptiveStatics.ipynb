# %% [markdown]
# **Assignment - 5 (Descriptive Statics)**

# %% [markdown]
# 1. A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?
#
# Answer - As we can see above data, The most frequently value is 12. For more analysis we calculate mean, mode, median.
#
# Data - 10,11,12,12,13,14,15
#
# Mean - 10+11+12+12+13+14+15/7= 12.42.
#
# Median - The middle for above data is - 12.
#
# Mode - 12 is the most frequently number in available data.
#
# So we can say 12 provides a performance of daily sale.

# %% [markdown]
#  2. teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
#
# Answer - Quiz Marks = 12,15,14,16,18,20,19
#
# Mean - 12+15+14+16+18+20+29/7 = 16.28
#
# So we can say 16.28 represents the average performance of the class and it shows good understanding level of students.

# %% [markdown]
# 3. A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
#
# Answer - Shoe Sale Data - 7,7,8,8,8,9,9,10
#
# Most frequently number in above data is = 8 and it shows higher sales of size 8 shoes. It is helpful for the store managre for maintain stock and increase sales.

# %% [markdown]
# 4. A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median?
#
# Answer - The median for above data is $10200.
#
# Mode - 8000+9500+10200+11000+50000/5=17740.
#
# Median is better than the mean in this case reason being outlier available in this data. And mean not provide correct average of prices.

# %% [markdown]
# 5. A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time?
#
# Answer - Range Formula - Maximum Range - Minimum Range
#          = 40 - 25 = 15.
#
# The range in above data is 15 minutes and it represents fastest anf slowest puzzle solving time of the students. A smaller range indicate concisitency of daily performance.

# %% [markdown]
# 6. A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging?
#
# Answer - Range = 120-98= 22Kg.
#
# The range is 22kg for the above data is helps the farmer understand the maximum fluctuation in harvest wright. It allows him to ensure enough packaging materials and mimimmum space for the harvested apples.

# %% [markdown]
# 7. Two delivery companies track delivery delays (in minutes).
# Company A: variance = 6
# Company B: variance = 15
# Which company is more consistent, and why?
#
# Answer - Variance measures how numbers are spread out from their average. High variance represents data is spread out and lower variance represents clustured data. So we can say Company A is more consistent in avareage of Company B.

# %% [markdown]
# 8. A finance student compares the daily price fluctuations of two cryptocurrencies.
# Coin A: standard deviation = $30
# Coin B: standard deviation = $120
# Which coin is riskier to invest in, and why?
#
# Answer - Standard deviation measures volatility. A higher standard deviation represents data is speard out and lower represents data is close to mean. So we can say Coin B is riskier to invest in.

# %% [markdown]
# 9. A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?
#
# Answer - Mean = 400+420+390+450+410/5 = 414 kwh.
#
# Standard Deviation - Approx 20.59
#
# ![image.png](data:image/png;base64,...)
#
# The average of electricity usage is = 414 kmh and the standard deviation is approx20.59 kwh. Their usage is failrly consistent with low monthly variation.

# %% [markdown]
# 10. A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide about the player’s scoring performance?
#
# Answer - Mean = 15+18+20+22+25+17+19+21/8 = 19.625
#
# Median = 19.5 reason being total numbersof values is even. So we calculate average of two middle value.
#
# Mode = The mode is not available here reason being all numbers appears only once.
#
# Range = Maximum range - Minimum range
#       =22-15 = 10
#
# Standard Deviation =    2.91
#
# ![image.png](data:image/png;base64,...)
#
# Mean and meadian represents symmetrical distribution of scores and low standard deviation represents consistency in the palyer's scoring
